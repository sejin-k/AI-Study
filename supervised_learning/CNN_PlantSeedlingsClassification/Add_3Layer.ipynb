# %%
! nvcc --version
# !cat /usr/local/cuda-9.0/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2017 NVIDIA Corporation
# Built on Fri_Sep__1_21:08:03_CDT_2017
# Cuda compilation tools, release 9.0, V9.0.176

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.8.0'

# %%
import sys
import os
import cv2
import time
import glob
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt



# # GPU setting
# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#     try:
#         tf.config.experimental.set_virtual_device_configuration(
#             gpus[1],
#             [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024)])
#         logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#         print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#     except RuntimeError as e:
#         # Virtual devices must be set before GPUs have been initialized
#         print(e)
# config = tf.ConfigProto()

# config.gpu_options.allow_growth = True
# os.environ["CUDA_VISIBLE_DEVICES"]='0'
        
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="1"
# config = tf.ConfigProto()
# config.gpu_options.allow_growth = True
# config.gpu_options.visible_device_list="1"

# %matplotlib inline

train_folder = 'Dataset/train'
val_folder = 'Dataset/validation'
test_folder = 'Dataset/test'

def _minmax_scaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    
    return numerator / (denominator + 1e-7)


def _one_hot(idx):
    idx = tf.one_hot(np.array(idx), 12).eval(session=tf.Session())
    
    return idx

def _shuffle(images, labels):
    tmp = [[x,y] for x, y in zip(images, labels)]
    random.shuffle(tmp)
    shuffle_images = [n[0] for n in tmp]
    shuffle_labels = [n[1] for n in tmp]
    
    return shuffle_images, shuffle_labels

def _data_load(folder_path):
    images = []
    labels = []
    folder_list = os.listdir(folder_path)
    for i, v in enumerate(folder_list):
        image_path = glob.glob(os.path.join(folder_path,v,'*.png')) 
        for j in image_path:
            images.append(cv2.imread(j))
            labels.append(i)
        
    return _minmax_scaler(images), _one_hot(labels)


train_images, train_labels = _data_load(train_folder)
val_images, val_labels = _data_load(val_folder)
test_images, test_labels = _data_load(test_folder)

print("train_images shape: ", np.array(train_images).shape, "// type: ", type(np.array(train_images)))
print("train_labels shape: ", np.array(train_labels).shape, "// type: ", type(np.array(train_labels)))
print("validation_images shape: ", np.array(val_images).shape, "// type: ", type(np.array(val_images)))
print("validation_labels shape: ", np.array(val_labels).shape, "// type: ", type(np.array(val_labels)))
print("test_images shape: ", np.array(test_images).shape, "// type: ", type(np.array(test_images)))
print("test_labels shape: ", np.array(test_labels).shape, "// type: ", type(np.array(test_labels)))
# Out:
# train_images shape:  (3847, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# train_labels shape:  (3847, 12) // type:  <class 'numpy.ndarray'>
# validation_images shape:  (447, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# validation_labels shape:  (447, 12) // type:  <class 'numpy.ndarray'>
# test_images shape:  (456, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# test_labels shape:  (456, 12) // type:  <class 'numpy.ndarray'>

# %%
learning_rate = 0.00001
batch_size = 64
n_epochs = 100

# Create placeholders
X = tf.placeholder(tf.float32,shape=[None,64,64,3], name="image")
Y = tf.placeholder(tf.int32,[None, 12], name="label")
#Y = tf.one_hot(Y, 12).eval(session=tf.Session())
#Y1 = tf.one_hot(Y, 12)
#Y2 = tf.reshape(Y1, [-1, 12])

#64x64x64
Kernel1 = tf.get_variable("Kernel1",shape=[3,3,3,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1 = tf.nn.conv2d(X, Kernel1, strides=[1,1,1,1], padding='SAME')+Bias1
Activation1 = tf.nn.relu(Conv1)

#32x32x64
Pool1 = tf.nn.max_pool(Activation1, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#32x32x128
Kernel2 = tf.get_variable("Kernel2",shape=[3,3,64,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2 = tf.nn.conv2d(Pool1, Kernel2, strides=[1,1,1,1], padding='SAME')+Bias2
Activation2 = tf.nn.relu(Conv2)

#16x16x128
Pool2 = tf.nn.max_pool(Activation2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#16x16x256
Kernel3_1 = tf.get_variable("Kernel3_1",shape=[3,3,128,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_1 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_1 = tf.nn.conv2d(Pool2, Kernel3_1, strides=[1,1,1,1], padding='SAME')+Bias3_1
Activation3_1 = tf.nn.relu(Conv3_1)

Kernel3_2 = tf.get_variable("Kernel3_2",shape=[3,3,256,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_2 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_2 = tf.nn.conv2d(Activation3_1, Kernel3_2, strides=[1,1,1,1], padding='SAME')+Bias3_2
Activation3_2 = tf.nn.relu(Conv3_2)

#8x8x256
Pool3 = tf.nn.max_pool(Activation3_2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#8x8x512
Kernel4_1 = tf.get_variable("Kernel4_1",shape=[3,3,256,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_1 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_1 = tf.nn.conv2d(Pool3, Kernel4_1, strides=[1,1,1,1], padding='SAME')+Bias4_1
Activation4_1 = tf.nn.relu(Conv4_1)

Kernel4_2 = tf.get_variable("Kernel4_2",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_2 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_2 = tf.nn.conv2d(Activation4_1, Kernel4_2, strides=[1,1,1,1], padding='SAME')+Bias4_2
Activation4_2 = tf.nn.relu(Conv4_2)

#4x4x512
Pool4 = tf.nn.max_pool(Activation4_2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

Kernel5_1 = tf.get_variable("Kernel5_1",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias5_1 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv5_1 = tf.nn.conv2d(Pool4, Kernel5_1, strides=[1,1,1,1], padding='SAME')+Bias5_1
Activation5_1 = tf.nn.relu(Conv5_1)

Kernel5_2 = tf.get_variable("Kernel5_2",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias5_2 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv5_2 = tf.nn.conv2d(Activation5_1, Kernel5_2, strides=[1,1,1,1], padding='SAME')+Bias5_2
Activation5_2 = tf.nn.relu(Conv5_2)

## 2*2*512
Pool5 = tf.nn.max_pool(Activation5_2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

# 2x2x1024
## Add DCNN Layer 1
Kernel6_1 = tf.get_variable("Kernel6_1",shape=[3,3,512,1024],initializer=tf.contrib.layers.xavier_initializer())
Bias6_1 = tf.Variable(tf.truncated_normal(shape=[1024],stddev=0.1))
Conv6_1 = tf.nn.conv2d(Pool5, Kernel6_1, strides=[1,1,1,1], padding='SAME')+Bias6_1
Activation6_1 = tf.nn.relu(Conv6_1)

# 2x2x1024
## Add DCNN Layer 2
Kernel6_2 = tf.get_variable("Kernel6_2",shape=[3,3,1024,1024],initializer=tf.contrib.layers.xavier_initializer())
Bias6_2 = tf.Variable(tf.truncated_normal(shape=[1024],stddev=0.1))
Conv6_2 = tf.nn.conv2d(Activation6_1, Kernel6_2, strides=[1,1,1,1], padding='SAME')+Bias6_2
Activation6_2 = tf.nn.relu(Conv6_2)

# 2x2x1024
## Add DCNN Layer 3
Kernel6_3 = tf.get_variable("Kernel6_3",shape=[3,3,1024,1024],initializer=tf.contrib.layers.xavier_initializer())
Bias6_3 = tf.Variable(tf.truncated_normal(shape=[1024],stddev=0.1))
Conv6_3 = tf.nn.conv2d(Activation6_2, Kernel6_3, strides=[1,1,1,1], padding='SAME')+Bias6_3
Activation7_1 = tf.nn.relu(Conv6_3)

# 1x1x1024
Pool6 = tf.nn.max_pool(Activation6_2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')


W1 = tf.get_variable("W1",shape=[1*1*1024, 1024],initializer=tf.contrib.layers.xavier_initializer())
B1 = tf.Variable(tf.truncated_normal(shape=[1024]))
Pool6_flat = tf.reshape(Pool6,[-1,1*1*1024])
fc7 = tf.matmul(Pool6_flat,W1)+B1
Activation7 = tf.nn.relu(fc7)

W2 = tf.get_variable("W2",shape=[1024, 12],initializer=tf.contrib.layers.xavier_initializer())
B2 = tf.Variable(tf.truncated_normal(shape=[12]))
OutputLayer = tf.matmul(Activation7 ,W2)+B2

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=OutputLayer, labels=Y))
#optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate,momentum=0.9).minimize(loss)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(OutputLayer,1),tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# %%
# Run optimization and test
loss_train_history = []
acc_train_history = []
loss_val_history = []
acc_val_history = []

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    n_batches = int(len(train_images)/batch_size)
    
    for i in range(n_epochs):  
        total_correct_train_preds = 0
        x_train, y_train =_shuffle(train_images, train_labels)
        for k in range(n_batches):
            X_train_batch, Y_train_batch = x_train[k*batch_size:k*batch_size+batch_size], \
                                           y_train[k*batch_size:k*batch_size+batch_size] 
            _, loss_train, OutputLayer_train_batch = sess.run([optimizer, loss, accuracy], \
                                                              feed_dict={X: X_train_batch, Y: Y_train_batch})
            total_correct_train_preds += OutputLayer_train_batch
        train_accuracy = total_correct_train_preds/n_batches
                
        
        # Check validation accuracy
        n_v_batches = int(len(val_images)/batch_size)
        total_correct_val_preds = 0
        for j in range(n_v_batches):
            X_val_batch, Y_val_batch = val_images[j*batch_size:j*batch_size+batch_size], \
                                       val_labels[j*batch_size:j*batch_size+batch_size] 
            loss_val, OutputLayer_val_batch = sess.run([loss, accuracy], feed_dict={X: X_val_batch, \
                                                                                    Y: Y_val_batch})
            total_correct_val_preds += OutputLayer_val_batch
        validation_accuracy = total_correct_val_preds/n_v_batches
           
        print('epoch:%d // train loss:%.3f // train accuracy:%.3f // val loss:%.3f // val accuracy:%.3f' \
              % (i, loss_train, train_accuracy, loss_val, validation_accuracy))
        loss_train_history.append(loss_train)
        acc_train_history.append(train_accuracy)
        loss_val_history.append(loss_val)
        acc_val_history.append(validation_accuracy)
        
        


    # Test the model
    n_batches = int(len(test_images)/batch_size)
    total_correct_test_preds = 0
    for i in range(n_batches):
        X_test_batch, Y_test_batch = test_images[i*batch_size:i*batch_size+batch_size], \
                                     test_labels[i*batch_size:i*batch_size+batch_size]
        OutputLayer_test_batch = sess.run(OutputLayer, feed_dict={X: X_test_batch, Y:Y_test_batch})
        preds = tf.nn.softmax(OutputLayer_test_batch)
        correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_test_batch, 1))
        accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32))
        total_correct_test_preds += sess.run(accuracy)
        
    print ("Test accuracy is {0}".format(total_correct_test_preds/len(test_images)))
# Out:
# epoch:0 // train loss:2.358 // train accuracy:0.100 // val loss:2.218 // val accuracy:0.130
# epoch:1 // train loss:2.468 // train accuracy:0.132 // val loss:2.190 // val accuracy:0.109
# epoch:2 // train loss:2.427 // train accuracy:0.138 // val loss:2.272 // val accuracy:0.109
# epoch:3 // train loss:2.568 // train accuracy:0.145 // val loss:2.177 // val accuracy:0.109
# epoch:4 // train loss:2.493 // train accuracy:0.139 // val loss:2.145 // val accuracy:0.135
# epoch:5 // train loss:2.371 // train accuracy:0.139 // val loss:2.117 // val accuracy:0.109
# epoch:6 // train loss:2.455 // train accuracy:0.157 // val loss:2.167 // val accuracy:0.172
# epoch:7 // train loss:2.463 // train accuracy:0.172 // val loss:2.331 // val accuracy:0.112
# epoch:8 // train loss:2.341 // train accuracy:0.179 // val loss:2.230 // val accuracy:0.201
# epoch:9 // train loss:2.042 // train accuracy:0.225 // val loss:2.040 // val accuracy:0.234
# epoch:10 // train loss:1.825 // train accuracy:0.276 // val loss:2.403 // val accuracy:0.271
# epoch:11 // train loss:1.661 // train accuracy:0.341 // val loss:2.051 // val accuracy:0.333
# epoch:12 // train loss:1.748 // train accuracy:0.372 // val loss:1.675 // val accuracy:0.336
# epoch:13 // train loss:1.851 // train accuracy:0.403 // val loss:1.666 // val accuracy:0.354
# epoch:14 // train loss:1.417 // train accuracy:0.424 // val loss:2.363 // val accuracy:0.359
# epoch:15 // train loss:1.448 // train accuracy:0.435 // val loss:2.242 // val accuracy:0.354
# epoch:16 // train loss:1.617 // train accuracy:0.449 // val loss:1.981 // val accuracy:0.383
# epoch:17 // train loss:1.240 // train accuracy:0.465 // val loss:2.011 // val accuracy:0.417
# epoch:18 // train loss:1.266 // train accuracy:0.478 // val loss:2.336 // val accuracy:0.380
# epoch:19 // train loss:1.341 // train accuracy:0.483 // val loss:2.116 // val accuracy:0.411
# epoch:20 // train loss:1.367 // train accuracy:0.499 // val loss:2.101 // val accuracy:0.414
# epoch:21 // train loss:1.157 // train accuracy:0.515 // val loss:1.530 // val accuracy:0.443
# epoch:22 // train loss:1.235 // train accuracy:0.508 // val loss:2.383 // val accuracy:0.393
# epoch:23 // train loss:1.482 // train accuracy:0.525 // val loss:1.871 // val accuracy:0.430
# epoch:24 // train loss:1.253 // train accuracy:0.534 // val loss:1.836 // val accuracy:0.443
# epoch:25 // train loss:1.516 // train accuracy:0.554 // val loss:1.828 // val accuracy:0.432
# epoch:26 // train loss:1.314 // train accuracy:0.561 // val loss:1.470 // val accuracy:0.432
# epoch:27 // train loss:1.393 // train accuracy:0.575 // val loss:2.243 // val accuracy:0.453
# epoch:28 // train loss:1.139 // train accuracy:0.572 // val loss:1.933 // val accuracy:0.435
# epoch:29 // train loss:1.073 // train accuracy:0.573 // val loss:1.646 // val accuracy:0.469
# epoch:30 // train loss:0.945 // train accuracy:0.589 // val loss:1.700 // val accuracy:0.458
# epoch:31 // train loss:1.006 // train accuracy:0.588 // val loss:1.813 // val accuracy:0.471
# epoch:32 // train loss:1.006 // train accuracy:0.601 // val loss:1.853 // val accuracy:0.477
# epoch:33 // train loss:1.104 // train accuracy:0.618 // val loss:1.938 // val accuracy:0.469
# epoch:34 // train loss:1.284 // train accuracy:0.612 // val loss:1.818 // val accuracy:0.529
# epoch:35 // train loss:1.159 // train accuracy:0.628 // val loss:1.631 // val accuracy:0.505
# epoch:36 // train loss:1.162 // train accuracy:0.632 // val loss:1.738 // val accuracy:0.510
# epoch:37 // train loss:0.938 // train accuracy:0.634 // val loss:1.590 // val accuracy:0.510
# epoch:38 // train loss:0.815 // train accuracy:0.641 // val loss:2.317 // val accuracy:0.477
# epoch:39 // train loss:0.970 // train accuracy:0.656 // val loss:1.477 // val accuracy:0.516
# epoch:40 // train loss:1.045 // train accuracy:0.658 // val loss:1.805 // val accuracy:0.505
# epoch:41 // train loss:1.154 // train accuracy:0.670 // val loss:1.684 // val accuracy:0.492
# epoch:42 // train loss:1.140 // train accuracy:0.670 // val loss:1.657 // val accuracy:0.521
# epoch:43 // train loss:0.961 // train accuracy:0.662 // val loss:1.550 // val accuracy:0.560
# epoch:44 // train loss:0.831 // train accuracy:0.680 // val loss:1.889 // val accuracy:0.536
# epoch:45 // train loss:0.916 // train accuracy:0.684 // val loss:1.892 // val accuracy:0.534
# epoch:46 // train loss:0.863 // train accuracy:0.686 // val loss:2.118 // val accuracy:0.508
# epoch:47 // train loss:0.922 // train accuracy:0.696 // val loss:2.132 // val accuracy:0.497
# epoch:48 // train loss:0.823 // train accuracy:0.695 // val loss:1.952 // val accuracy:0.510
# epoch:49 // train loss:0.747 // train accuracy:0.702 // val loss:1.939 // val accuracy:0.500
# epoch:50 // train loss:0.728 // train accuracy:0.715 // val loss:2.007 // val accuracy:0.542
# epoch:51 // train loss:0.860 // train accuracy:0.708 // val loss:2.484 // val accuracy:0.482
# epoch:52 // train loss:1.007 // train accuracy:0.720 // val loss:2.251 // val accuracy:0.513
# epoch:53 // train loss:0.668 // train accuracy:0.718 // val loss:1.434 // val accuracy:0.583
# epoch:54 // train loss:0.955 // train accuracy:0.716 // val loss:1.977 // val accuracy:0.562
# epoch:55 // train loss:0.810 // train accuracy:0.724 // val loss:2.244 // val accuracy:0.526
# epoch:56 // train loss:0.654 // train accuracy:0.723 // val loss:1.416 // val accuracy:0.609
# epoch:57 // train loss:0.850 // train accuracy:0.725 // val loss:1.572 // val accuracy:0.583
# epoch:58 // train loss:0.702 // train accuracy:0.743 // val loss:1.651 // val accuracy:0.596
# epoch:59 // train loss:0.900 // train accuracy:0.733 // val loss:1.846 // val accuracy:0.573
# epoch:60 // train loss:0.893 // train accuracy:0.750 // val loss:1.968 // val accuracy:0.583
# epoch:61 // train loss:0.745 // train accuracy:0.738 // val loss:1.202 // val accuracy:0.643
# epoch:62 // train loss:0.667 // train accuracy:0.745 // val loss:1.549 // val accuracy:0.617
# epoch:63 // train loss:0.769 // train accuracy:0.758 // val loss:1.455 // val accuracy:0.641
# epoch:64 // train loss:0.742 // train accuracy:0.761 // val loss:1.400 // val accuracy:0.630
# epoch:65 // train loss:0.530 // train accuracy:0.765 // val loss:1.958 // val accuracy:0.581
# epoch:66 // train loss:0.905 // train accuracy:0.758 // val loss:1.754 // val accuracy:0.630
# epoch:67 // train loss:0.772 // train accuracy:0.769 // val loss:1.708 // val accuracy:0.560
# epoch:68 // train loss:0.587 // train accuracy:0.761 // val loss:1.410 // val accuracy:0.617
# epoch:69 // train loss:0.611 // train accuracy:0.771 // val loss:1.602 // val accuracy:0.630
# epoch:70 // train loss:0.591 // train accuracy:0.787 // val loss:1.599 // val accuracy:0.628
# epoch:71 // train loss:0.580 // train accuracy:0.784 // val loss:1.760 // val accuracy:0.628
# epoch:72 // train loss:0.569 // train accuracy:0.774 // val loss:2.783 // val accuracy:0.523
# epoch:73 // train loss:0.663 // train accuracy:0.779 // val loss:2.026 // val accuracy:0.578
# epoch:74 // train loss:0.462 // train accuracy:0.789 // val loss:1.596 // val accuracy:0.643
# epoch:75 // train loss:0.656 // train accuracy:0.795 // val loss:2.064 // val accuracy:0.599
# epoch:76 // train loss:0.559 // train accuracy:0.796 // val loss:1.681 // val accuracy:0.635
# epoch:77 // train loss:0.537 // train accuracy:0.805 // val loss:2.309 // val accuracy:0.570
# epoch:78 // train loss:0.570 // train accuracy:0.809 // val loss:1.593 // val accuracy:0.641
# epoch:79 // train loss:0.738 // train accuracy:0.808 // val loss:2.337 // val accuracy:0.576
# epoch:80 // train loss:0.571 // train accuracy:0.817 // val loss:1.588 // val accuracy:0.615
# epoch:81 // train loss:0.585 // train accuracy:0.813 // val loss:1.817 // val accuracy:0.615
# epoch:82 // train loss:0.589 // train accuracy:0.819 // val loss:2.872 // val accuracy:0.534
# epoch:83 // train loss:0.509 // train accuracy:0.811 // val loss:2.517 // val accuracy:0.586
# epoch:84 // train loss:0.287 // train accuracy:0.816 // val loss:2.594 // val accuracy:0.549
# epoch:85 // train loss:0.592 // train accuracy:0.831 // val loss:2.385 // val accuracy:0.612
# epoch:86 // train loss:0.525 // train accuracy:0.825 // val loss:2.137 // val accuracy:0.604
# epoch:87 // train loss:0.501 // train accuracy:0.825 // val loss:1.841 // val accuracy:0.625
# epoch:88 // train loss:0.444 // train accuracy:0.842 // val loss:2.175 // val accuracy:0.612
# epoch:89 // train loss:0.349 // train accuracy:0.835 // val loss:2.544 // val accuracy:0.583
# epoch:90 // train loss:0.413 // train accuracy:0.834 // val loss:1.782 // val accuracy:0.622
# epoch:91 // train loss:0.511 // train accuracy:0.849 // val loss:2.728 // val accuracy:0.547
# epoch:92 // train loss:0.464 // train accuracy:0.845 // val loss:2.796 // val accuracy:0.560
# epoch:93 // train loss:0.415 // train accuracy:0.838 // val loss:1.496 // val accuracy:0.659
# epoch:94 // train loss:0.415 // train accuracy:0.846 // val loss:2.892 // val accuracy:0.565
# epoch:95 // train loss:0.474 // train accuracy:0.853 // val loss:2.511 // val accuracy:0.607
# epoch:96 // train loss:0.425 // train accuracy:0.853 // val loss:1.262 // val accuracy:0.677
# epoch:97 // train loss:0.756 // train accuracy:0.852 // val loss:2.834 // val accuracy:0.594
# epoch:98 // train loss:0.391 // train accuracy:0.855 // val loss:1.752 // val accuracy:0.638
# epoch:99 // train loss:0.460 // train accuracy:0.859 // val loss:2.066 // val accuracy:0.648
# Test accuracy is 0.5986842105263158

# %%
plt.subplot(2,1,1)
plt.plot(loss_train_history, 'b-', label='Train loss value')
plt.plot(loss_val_history, 'r-', label='Val. loss value')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(ncol=2, loc='upper right')

plt.subplot(2,1,2)
plt.plot(acc_train_history, 'b-', label='Train accuracy value')
plt.plot(acc_val_history, 'r-', label='Val. accuracy value')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(10, 10)
plt.show()
