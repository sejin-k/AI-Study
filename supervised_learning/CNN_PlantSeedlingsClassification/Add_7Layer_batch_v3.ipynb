# %%
! nvcc --version
# !cat /usr/local/cuda-9.0/include/cudnn.h | grep CUDNN_MAJOR -A 2
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2017 NVIDIA Corporation
# Built on Fri_Sep__1_21:08:03_CDT_2017
# Cuda compilation tools, release 9.0, V9.0.176

# %%
import tensorflow as tf
# !cat /usr/local/cuda-9.0/include/cudnn.h | grep CUDNN_MAJOR -A 2
tf.__version__
# Out:
# '1.8.0'

# %%
import sys
import os
import cv2
import time
import glob
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib inline

train_folder = 'Dataset/train'
val_folder = 'Dataset/validation'
test_folder = 'Dataset/test'

def _minmax_scaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    
    return numerator / (denominator + 1e-7)


def _one_hot(idx):
    idx = tf.one_hot(np.array(idx), 12).eval(session=tf.Session())
    
    return idx

def _shuffle(images, labels):
    tmp = [[x,y] for x, y in zip(images, labels)]
    random.shuffle(tmp)
    shuffle_images = [n[0] for n in tmp]
    shuffle_labels = [n[1] for n in tmp]
    
    return shuffle_images, shuffle_labels

def _data_load(folder_path):
    images = []
    labels = []
    folder_list = os.listdir(folder_path)
    for i, v in enumerate(folder_list):
        image_path = glob.glob(os.path.join(folder_path,v,'*.png')) 
        for j in image_path:
            images.append(cv2.imread(j))
            labels.append(i)
        
    return _minmax_scaler(images), _one_hot(labels)


train_images, train_labels = _data_load(train_folder)
val_images, val_labels = _data_load(val_folder)
test_images, test_labels = _data_load(test_folder)

print("train_images shape: ", np.array(train_images).shape, "// type: ", type(np.array(train_images)))
print("train_labels shape: ", np.array(train_labels).shape, "// type: ", type(np.array(train_labels)))
print("validation_images shape: ", np.array(val_images).shape, "// type: ", type(np.array(val_images)))
print("validation_labels shape: ", np.array(val_labels).shape, "// type: ", type(np.array(val_labels)))
print("test_images shape: ", np.array(test_images).shape, "// type: ", type(np.array(test_images)))
print("test_labels shape: ", np.array(test_labels).shape, "// type: ", type(np.array(test_labels)))
# Out:
# train_images shape:  (3847, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# train_labels shape:  (3847, 12) // type:  <class 'numpy.ndarray'>
# validation_images shape:  (447, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# validation_labels shape:  (447, 12) // type:  <class 'numpy.ndarray'>
# test_images shape:  (456, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# test_labels shape:  (456, 12) // type:  <class 'numpy.ndarray'>

# %%
learning_rate = 0.00001
batch_size = 64
n_epochs = 100

# Create placeholders
X = tf.placeholder(tf.float32,shape=[None,64,64,3], name="image")
Y = tf.placeholder(tf.int32,[None, 12], name="label")
#Y = tf.one_hot(Y, 12).eval(session=tf.Session())
#Y1 = tf.one_hot(Y, 12)
#Y2 = tf.reshape(Y1, [-1, 12])
batch_prob = tf.placeholder(tf.bool)

#64x64x64
Kernel1_1 = tf.get_variable("Kernel1_1",shape=[3,3,3,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1_1 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1_1 = tf.nn.conv2d(X, Kernel1_1, strides=[1,1,1,1], padding='SAME')+Bias1_1
Conv1_1 = tf.layers.batch_normalization(Conv1_1, center=True, scale=True, training=batch_prob)
Activation1_1 = tf.nn.relu(Conv1_1)

#64x64x64
Kernel1_2 = tf.get_variable("Kernel1_2",shape=[3,3,64,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1_2 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1_2 = tf.nn.conv2d(Activation1_1, Kernel1_2, strides=[1,1,1,1], padding='SAME')+Bias1_2
Conv1_2 = tf.layers.batch_normalization(Conv1_2, center=True, scale=True, training=batch_prob)
Activation1_2 = tf.nn.relu(Conv1_2)

#64x64x64
Kernel1_3 = tf.get_variable("Kernel1_3",shape=[3,3,64,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1_3 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1_3 = tf.nn.conv2d(Activation1_2, Kernel1_3, strides=[1,1,1,1], padding='SAME')+Bias1_3
Conv1_3 = tf.layers.batch_normalization(Conv1_3, center=True, scale=True, training=batch_prob)
Activation1_3 = tf.nn.relu(Conv1_3)

#32x32x64
Pool1 = tf.nn.max_pool(Activation1_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#32x32x128
Kernel2_1 = tf.get_variable("Kernel2_1",shape=[3,3,64,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2_1 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2_1 = tf.nn.conv2d(Pool1, Kernel2_1, strides=[1,1,1,1], padding='SAME')+Bias2_1
Conv2_1 = tf.layers.batch_normalization(Conv2_1, center=True, scale=True, training=batch_prob)
Activation2_1 = tf.nn.relu(Conv2_1)

#32x32x128
Kernel2_2 = tf.get_variable("Kernel2_2",shape=[3,3,128,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2_2 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2_2 = tf.nn.conv2d(Activation2_1, Kernel2_2, strides=[1,1,1,1], padding='SAME')+Bias2_2
Conv2_2 = tf.layers.batch_normalization(Conv2_2, center=True, scale=True, training=batch_prob)
Activation2_2 = tf.nn.relu(Conv2_2)

#32x32x128
Kernel2_3 = tf.get_variable("Kernel2_3",shape=[3,3,128,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2_3 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2_3 = tf.nn.conv2d(Activation2_2, Kernel2_3, strides=[1,1,1,1], padding='SAME')+Bias2_3
Conv2_3 = tf.layers.batch_normalization(Conv2_3, center=True, scale=True, training=batch_prob)
Activation2_3 = tf.nn.relu(Conv2_3)

#16x16x128
Pool2 = tf.nn.max_pool(Activation2_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#16x16x256
Kernel3_1 = tf.get_variable("Kernel3_1",shape=[3,3,128,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_1 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_1 = tf.nn.conv2d(Pool2, Kernel3_1, strides=[1,1,1,1], padding='SAME')+Bias3_1
Conv3_1 = tf.layers.batch_normalization(Conv3_1, center=True, scale=True, training=batch_prob)
Activation3_1 = tf.nn.relu(Conv3_1)

#16x16x256
Kernel3_2 = tf.get_variable("Kernel3_2",shape=[3,3,256,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_2 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_2 = tf.nn.conv2d(Activation3_1, Kernel3_2, strides=[1,1,1,1], padding='SAME')+Bias3_2
Conv3_2 = tf.layers.batch_normalization(Conv3_2, center=True, scale=True, training=batch_prob)
Activation3_2 = tf.nn.relu(Conv3_2)

#16x16x256
## Add DCNN Layer 1
Kernel3_3 = tf.get_variable("Kernel3_3",shape=[3,3,256,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_3 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_3 = tf.nn.conv2d(Activation3_2, Kernel3_3, strides=[1,1,1,1], padding='SAME')+Bias3_3
Conv3_3 = tf.layers.batch_normalization(Conv3_3, center=True, scale=True, training=batch_prob)
Activation3_3 = tf.nn.relu(Conv3_3)

#8x8x512
Pool3 = tf.nn.max_pool(Activation3_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#8x8x512
## Add DCNN Layer 2
Kernel4_1 = tf.get_variable("Kernel4_1",shape=[3,3,256,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_1 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_1 = tf.nn.conv2d(Pool3, Kernel4_1, strides=[1,1,1,1], padding='SAME')+Bias4_1
Conv4_1 = tf.layers.batch_normalization(Conv4_1, center=True, scale=True, training=batch_prob)
Activation4_1 = tf.nn.relu(Conv4_1)

#8x8x512
## Add DCNN Layer 3
Kernel4_2 = tf.get_variable("Kernel4_2",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_2 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_2 = tf.nn.conv2d(Activation4_1, Kernel4_2, strides=[1,1,1,1], padding='SAME')+Bias4_2
Conv4_2 = tf.layers.batch_normalization(Conv4_2, center=True, scale=True, training=batch_prob)
Activation4_2 = tf.nn.relu(Conv4_2)

#8x8x512
## Add DCNN Layer 4
Kernel4_3 = tf.get_variable("Kernel4_3",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_3 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_3 = tf.nn.conv2d(Activation4_2, Kernel4_3, strides=[1,1,1,1], padding='SAME')+Bias4_3
Conv4_3 = tf.layers.batch_normalization(Conv4_3, center=True, scale=True, training=batch_prob)
Activation4_3 = tf.nn.relu(Conv4_3)

#4x4x512
Pool4 = tf.nn.max_pool(Activation4_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#4x4x1024
## Add DCNN Layer 5
Kernel5_1 = tf.get_variable("Kernel5_1",shape=[3,3,512,1024],initializer=tf.contrib.layers.xavier_initializer())
Bias5_1 = tf.Variable(tf.truncated_normal(shape=[1024],stddev=0.1))
Conv5_1 = tf.nn.conv2d(Pool4, Kernel5_1, strides=[1,1,1,1], padding='SAME')+Bias5_1
Conv5_1 = tf.layers.batch_normalization(Conv5_1, center=True, scale=True, training=batch_prob)
Activation5_1 = tf.nn.relu(Conv5_1)

#4x4x1024
## Add DCNN Layer 6
Kernel5_2 = tf.get_variable("Kernel5_2",shape=[3,3,1024,1024],initializer=tf.contrib.layers.xavier_initializer())
Bias5_2 = tf.Variable(tf.truncated_normal(shape=[1024],stddev=0.1))
Conv5_2 = tf.nn.conv2d(Activation5_1, Kernel5_2, strides=[1,1,1,1], padding='SAME')+Bias5_2
Conv5_2 = tf.layers.batch_normalization(Conv5_2, center=True, scale=True, training=batch_prob)
Activation5_2 = tf.nn.relu(Conv5_2)

#4x4x1024
## Add DCNN Layer 7
Kernel5_3 = tf.get_variable("Kernel5_3",shape=[3,3,1024,2048],initializer=tf.contrib.layers.xavier_initializer())
Bias5_3 = tf.Variable(tf.truncated_normal(shape=[2048],stddev=0.1))
Conv5_3 = tf.nn.conv2d(Activation5_2, Kernel5_3, strides=[1,1,1,1], padding='SAME')+Bias5_3
Conv5_3 = tf.layers.batch_normalization(Conv5_3, center=True, scale=True, training=batch_prob)
Activation5_3 = tf.nn.relu(Conv5_3)

#2x2x1024
Pool5 = tf.nn.max_pool(Activation5_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

W1 = tf.get_variable("W1",shape=[2*2*2048, 2048],initializer=tf.contrib.layers.xavier_initializer())
B1 = tf.Variable(tf.truncated_normal(shape=[2048]))
Pool5_flat = tf.reshape(Pool5,[-1,2*2*2048])
Pool5_flat = tf.layers.batch_normalization(Pool5_flat, center=True, scale=True, training=batch_prob)
fc6 = tf.matmul(Pool5_flat,W1)+B1
Activation6 = tf.nn.relu(fc6)

W2 = tf.get_variable("W2",shape=[2048, 12],initializer=tf.contrib.layers.xavier_initializer())
B2 = tf.Variable(tf.truncated_normal(shape=[12]))
OutputLayer = tf.matmul(Activation6 ,W2)+B2

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=OutputLayer, labels=Y))
#optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate,momentum=0.9).minimize(loss)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(OutputLayer,1),tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# %%
# Run optimization and test
loss_train_history = []
acc_train_history = []
loss_val_history = []
acc_val_history = []

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    n_batches = int(len(train_images)/batch_size)
    
    for i in range(n_epochs):  
        total_correct_train_preds = 0
        x_train, y_train =_shuffle(train_images, train_labels)
        for k in range(n_batches):
            X_train_batch, Y_train_batch = x_train[k*batch_size:k*batch_size+batch_size], \
                                           y_train[k*batch_size:k*batch_size+batch_size] 
            _, loss_train, OutputLayer_train_batch = sess.run([optimizer, loss, accuracy], \
                                                              feed_dict={X: X_train_batch, Y: Y_train_batch, batch_prob: True})
            total_correct_train_preds += OutputLayer_train_batch
        train_accuracy = total_correct_train_preds/n_batches
                
        
        # Check validation accuracy
        n_v_batches = int(len(val_images)/batch_size)
        total_correct_val_preds = 0
        for j in range(n_v_batches):
            X_val_batch, Y_val_batch = val_images[j*batch_size:j*batch_size+batch_size], \
                                       val_labels[j*batch_size:j*batch_size+batch_size] 
            loss_val, OutputLayer_val_batch = sess.run([loss, accuracy], feed_dict={X: X_val_batch, \
                                                                                    Y: Y_val_batch, \
                                                                                    batch_prob: True})
            total_correct_val_preds += OutputLayer_val_batch
        validation_accuracy = total_correct_val_preds/n_v_batches
           
        print('epoch:%d // train loss:%.3f // train accuracy:%.3f // val loss:%.3f // val accuracy:%.3f' \
              % (i, loss_train, train_accuracy, loss_val, validation_accuracy))
        loss_train_history.append(loss_train)
        acc_train_history.append(train_accuracy)
        loss_val_history.append(loss_val)
        acc_val_history.append(validation_accuracy)
        
        


    # Test the model
    n_batches = int(len(test_images)/batch_size)
    total_correct_test_preds = 0
    for i in range(n_batches):
        X_test_batch, Y_test_batch = test_images[i*batch_size:i*batch_size+batch_size], \
                                     test_labels[i*batch_size:i*batch_size+batch_size]
        OutputLayer_test_batch = sess.run(OutputLayer, feed_dict={X: X_test_batch, Y:Y_test_batch, batch_prob: True})
        preds = tf.nn.softmax(OutputLayer_test_batch)
        correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_test_batch, 1))
        accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32))
        total_correct_test_preds += sess.run(accuracy)
        
    print ("Test accuracy is {0}".format(total_correct_test_preds/len(test_images)))
# Out:
# epoch:0 // train loss:1.838 // train accuracy:0.327 // val loss:2.612 // val accuracy:0.255
# epoch:1 // train loss:0.819 // train accuracy:0.720 // val loss:2.458 // val accuracy:0.310
# epoch:2 // train loss:0.609 // train accuracy:0.879 // val loss:2.446 // val accuracy:0.292
# epoch:3 // train loss:0.261 // train accuracy:0.955 // val loss:2.316 // val accuracy:0.341
# epoch:4 // train loss:0.110 // train accuracy:0.983 // val loss:2.483 // val accuracy:0.333
# epoch:5 // train loss:0.075 // train accuracy:0.989 // val loss:2.570 // val accuracy:0.333
# epoch:6 // train loss:0.089 // train accuracy:0.994 // val loss:2.520 // val accuracy:0.352
# epoch:7 // train loss:0.039 // train accuracy:0.993 // val loss:2.636 // val accuracy:0.339
# epoch:8 // train loss:0.090 // train accuracy:0.995 // val loss:2.612 // val accuracy:0.346
# epoch:9 // train loss:0.014 // train accuracy:0.998 // val loss:2.595 // val accuracy:0.367
# epoch:10 // train loss:0.072 // train accuracy:0.997 // val loss:2.552 // val accuracy:0.365
# epoch:11 // train loss:0.008 // train accuracy:0.999 // val loss:2.659 // val accuracy:0.378
# epoch:12 // train loss:0.028 // train accuracy:0.999 // val loss:2.720 // val accuracy:0.370
# epoch:13 // train loss:0.006 // train accuracy:0.999 // val loss:2.748 // val accuracy:0.354
# epoch:14 // train loss:0.018 // train accuracy:1.000 // val loss:2.703 // val accuracy:0.383
# epoch:15 // train loss:0.006 // train accuracy:0.999 // val loss:2.725 // val accuracy:0.372
# epoch:16 // train loss:0.007 // train accuracy:1.000 // val loss:2.776 // val accuracy:0.372
# epoch:17 // train loss:0.007 // train accuracy:1.000 // val loss:2.753 // val accuracy:0.372
# epoch:18 // train loss:0.005 // train accuracy:1.000 // val loss:2.901 // val accuracy:0.383
# epoch:19 // train loss:0.006 // train accuracy:1.000 // val loss:2.812 // val accuracy:0.375
# epoch:20 // train loss:0.002 // train accuracy:1.000 // val loss:2.813 // val accuracy:0.375
# epoch:21 // train loss:0.007 // train accuracy:1.000 // val loss:2.838 // val accuracy:0.370
# epoch:22 // train loss:0.005 // train accuracy:0.999 // val loss:2.760 // val accuracy:0.367
# epoch:23 // train loss:0.004 // train accuracy:1.000 // val loss:2.796 // val accuracy:0.380
# epoch:24 // train loss:0.004 // train accuracy:1.000 // val loss:2.855 // val accuracy:0.380
# epoch:25 // train loss:0.028 // train accuracy:0.997 // val loss:2.783 // val accuracy:0.370
# epoch:26 // train loss:0.003 // train accuracy:1.000 // val loss:2.845 // val accuracy:0.388
# epoch:27 // train loss:0.002 // train accuracy:1.000 // val loss:2.887 // val accuracy:0.388
# epoch:28 // train loss:0.003 // train accuracy:0.999 // val loss:2.703 // val accuracy:0.378
# epoch:29 // train loss:0.004 // train accuracy:1.000 // val loss:2.852 // val accuracy:0.414
# epoch:30 // train loss:0.001 // train accuracy:1.000 // val loss:2.914 // val accuracy:0.404
# epoch:31 // train loss:0.001 // train accuracy:1.000 // val loss:2.820 // val accuracy:0.401
# epoch:32 // train loss:0.006 // train accuracy:1.000 // val loss:2.939 // val accuracy:0.391
# epoch:33 // train loss:0.004 // train accuracy:1.000 // val loss:2.988 // val accuracy:0.383
# epoch:34 // train loss:0.003 // train accuracy:1.000 // val loss:2.884 // val accuracy:0.378
# epoch:35 // train loss:0.004 // train accuracy:1.000 // val loss:2.940 // val accuracy:0.378
# epoch:36 // train loss:0.001 // train accuracy:1.000 // val loss:2.985 // val accuracy:0.393
# epoch:37 // train loss:0.001 // train accuracy:1.000 // val loss:3.014 // val accuracy:0.383
# epoch:38 // train loss:0.000 // train accuracy:1.000 // val loss:2.920 // val accuracy:0.372
# epoch:39 // train loss:0.001 // train accuracy:1.000 // val loss:2.975 // val accuracy:0.383
# epoch:40 // train loss:0.007 // train accuracy:1.000 // val loss:3.004 // val accuracy:0.385
# epoch:41 // train loss:0.001 // train accuracy:1.000 // val loss:3.049 // val accuracy:0.380
# epoch:42 // train loss:0.000 // train accuracy:1.000 // val loss:3.039 // val accuracy:0.393
# epoch:43 // train loss:0.001 // train accuracy:1.000 // val loss:2.941 // val accuracy:0.378
# epoch:44 // train loss:0.005 // train accuracy:0.999 // val loss:2.952 // val accuracy:0.388
# epoch:45 // train loss:0.001 // train accuracy:1.000 // val loss:3.042 // val accuracy:0.404
# epoch:46 // train loss:0.001 // train accuracy:1.000 // val loss:2.929 // val accuracy:0.401
# epoch:47 // train loss:0.001 // train accuracy:1.000 // val loss:2.959 // val accuracy:0.409
# epoch:48 // train loss:0.001 // train accuracy:1.000 // val loss:2.963 // val accuracy:0.409
# epoch:49 // train loss:0.001 // train accuracy:1.000 // val loss:2.979 // val accuracy:0.419
# epoch:50 // train loss:0.002 // train accuracy:1.000 // val loss:3.032 // val accuracy:0.404
# epoch:51 // train loss:0.002 // train accuracy:0.999 // val loss:3.172 // val accuracy:0.378
# epoch:52 // train loss:0.003 // train accuracy:0.999 // val loss:3.439 // val accuracy:0.380
# epoch:53 // train loss:0.184 // train accuracy:0.978 // val loss:3.560 // val accuracy:0.341
# epoch:54 // train loss:0.294 // train accuracy:0.941 // val loss:3.700 // val accuracy:0.367
# epoch:55 // train loss:0.064 // train accuracy:0.973 // val loss:3.015 // val accuracy:0.393
# epoch:56 // train loss:0.026 // train accuracy:0.996 // val loss:3.103 // val accuracy:0.404
# epoch:57 // train loss:0.002 // train accuracy:1.000 // val loss:3.173 // val accuracy:0.414
# epoch:58 // train loss:0.002 // train accuracy:0.999 // val loss:3.059 // val accuracy:0.419
# epoch:59 // train loss:0.047 // train accuracy:0.999 // val loss:2.908 // val accuracy:0.417
# epoch:60 // train loss:0.004 // train accuracy:1.000 // val loss:2.988 // val accuracy:0.419
# epoch:61 // train loss:0.003 // train accuracy:1.000 // val loss:3.111 // val accuracy:0.427
# epoch:62 // train loss:0.001 // train accuracy:1.000 // val loss:3.116 // val accuracy:0.414
# epoch:63 // train loss:0.020 // train accuracy:1.000 // val loss:3.189 // val accuracy:0.411
# epoch:64 // train loss:0.006 // train accuracy:1.000 // val loss:3.302 // val accuracy:0.414
# epoch:65 // train loss:0.000 // train accuracy:1.000 // val loss:3.155 // val accuracy:0.409
# epoch:66 // train loss:0.005 // train accuracy:1.000 // val loss:3.129 // val accuracy:0.409
# epoch:67 // train loss:0.000 // train accuracy:1.000 // val loss:3.029 // val accuracy:0.404
# epoch:68 // train loss:0.000 // train accuracy:1.000 // val loss:3.138 // val accuracy:0.414
# epoch:69 // train loss:0.000 // train accuracy:1.000 // val loss:3.218 // val accuracy:0.419
# epoch:70 // train loss:0.000 // train accuracy:1.000 // val loss:3.113 // val accuracy:0.411
# epoch:71 // train loss:0.002 // train accuracy:1.000 // val loss:3.134 // val accuracy:0.411
# epoch:72 // train loss:0.004 // train accuracy:1.000 // val loss:3.311 // val accuracy:0.424
# epoch:73 // train loss:0.001 // train accuracy:1.000 // val loss:3.245 // val accuracy:0.424
# epoch:74 // train loss:0.000 // train accuracy:1.000 // val loss:3.266 // val accuracy:0.411
# epoch:75 // train loss:0.000 // train accuracy:1.000 // val loss:3.380 // val accuracy:0.404
# epoch:76 // train loss:0.002 // train accuracy:1.000 // val loss:3.337 // val accuracy:0.414
# epoch:77 // train loss:0.000 // train accuracy:1.000 // val loss:3.379 // val accuracy:0.409
# epoch:78 // train loss:0.000 // train accuracy:1.000 // val loss:3.344 // val accuracy:0.409
# epoch:79 // train loss:0.000 // train accuracy:1.000 // val loss:3.358 // val accuracy:0.411
# epoch:80 // train loss:0.000 // train accuracy:1.000 // val loss:3.180 // val accuracy:0.417
# epoch:81 // train loss:0.000 // train accuracy:1.000 // val loss:3.211 // val accuracy:0.424
# epoch:82 // train loss:0.001 // train accuracy:0.999 // val loss:3.953 // val accuracy:0.417
# epoch:83 // train loss:0.001 // train accuracy:1.000 // val loss:3.337 // val accuracy:0.411
# epoch:84 // train loss:0.000 // train accuracy:1.000 // val loss:3.350 // val accuracy:0.417
# epoch:85 // train loss:0.001 // train accuracy:1.000 // val loss:3.261 // val accuracy:0.427
# epoch:86 // train loss:0.000 // train accuracy:1.000 // val loss:3.290 // val accuracy:0.422
# epoch:87 // train loss:0.000 // train accuracy:1.000 // val loss:3.271 // val accuracy:0.435
# epoch:88 // train loss:0.000 // train accuracy:1.000 // val loss:3.298 // val accuracy:0.435
# epoch:89 // train loss:0.001 // train accuracy:0.999 // val loss:3.362 // val accuracy:0.414
# epoch:90 // train loss:0.001 // train accuracy:1.000 // val loss:3.232 // val accuracy:0.443
# epoch:91 // train loss:0.000 // train accuracy:1.000 // val loss:3.292 // val accuracy:0.427
# epoch:92 // train loss:0.001 // train accuracy:1.000 // val loss:3.320 // val accuracy:0.432
# epoch:93 // train loss:0.000 // train accuracy:1.000 // val loss:3.298 // val accuracy:0.438
# epoch:94 // train loss:0.000 // train accuracy:1.000 // val loss:3.524 // val accuracy:0.443
# epoch:95 // train loss:0.000 // train accuracy:1.000 // val loss:3.495 // val accuracy:0.432
# epoch:96 // train loss:0.000 // train accuracy:1.000 // val loss:3.785 // val accuracy:0.411
# epoch:97 // train loss:0.000 // train accuracy:1.000 // val loss:3.814 // val accuracy:0.432
# epoch:98 // train loss:0.000 // train accuracy:1.000 // val loss:3.731 // val accuracy:0.422
# epoch:99 // train loss:0.000 // train accuracy:1.000 // val loss:3.710 // val accuracy:0.409
# Test accuracy is 0.3092105263157895

# %%
plt.subplot(2,1,1)
plt.plot(loss_train_history, 'b-', label='Train loss value')
plt.plot(loss_val_history, 'r-', label='Val. loss value')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(ncol=2, loc='upper right')

plt.subplot(2,1,2)
plt.plot(acc_train_history, 'b-', label='Train accuracy value')
plt.plot(acc_val_history, 'r-', label='Val. accuracy value')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(10, 10)
plt.show()
