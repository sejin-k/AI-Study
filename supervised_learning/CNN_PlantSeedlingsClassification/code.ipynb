# %%
import sys
import os
import cv2
import time
import glob
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib inline

train_folder = '../../../mid_term_project/Dataset/train'
val_folder = '../../../mid_term_project/Dataset/validation'
test_folder = '../../../mid_term_project/Dataset/test'

def _minmax_scaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    
    return numerator / (denominator + 1e-7)


def _one_hot(idx):
    idx = tf.one_hot(np.array(idx), 12).eval(session=tf.Session())
    
    return idx

def _shuffle(images, labels):
    tmp = [[x,y] for x, y in zip(images, labels)]
    random.shuffle(tmp)
    shuffle_images = [n[0] for n in tmp]
    shuffle_labels = [n[1] for n in tmp]
    
    return shuffle_images, shuffle_labels

def _data_load(folder_path):
    images = []
    labels = []
    folder_list = os.listdir(folder_path)
    for i, v in enumerate(folder_list):
        image_path = glob.glob(os.path.join(folder_path,v,'*.png')) 
        for j in image_path:
            images.append(cv2.imread(j))
            labels.append(i)
        
    return _minmax_scaler(images), _one_hot(labels)


train_images, train_labels = _data_load(train_folder)
val_images, val_labels = _data_load(val_folder)
test_images, test_labels = _data_load(test_folder)

print("train_images shape: ", np.array(train_images).shape, "// type: ", type(np.array(train_images)))
print("train_labels shape: ", np.array(train_labels).shape, "// type: ", type(np.array(train_labels)))
print("validation_images shape: ", np.array(val_images).shape, "// type: ", type(np.array(val_images)))
print("validation_labels shape: ", np.array(val_labels).shape, "// type: ", type(np.array(val_labels)))
print("test_images shape: ", np.array(test_images).shape, "// type: ", type(np.array(test_images)))
print("test_labels shape: ", np.array(test_labels).shape, "// type: ", type(np.array(test_labels)))
# Out:
# train_images shape:  (3847, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# train_labels shape:  (3847, 12) // type:  <class 'numpy.ndarray'>
# validation_images shape:  (447, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# validation_labels shape:  (447, 12) // type:  <class 'numpy.ndarray'>
# test_images shape:  (456, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# test_labels shape:  (456, 12) // type:  <class 'numpy.ndarray'>

# %%
learning_rate = 0.00001
batch_size = 64
n_epochs = 100

# Create placeholders
X = tf.placeholder(tf.float32,shape=[None,64,64,3], name="image")
Y = tf.placeholder(tf.int32,[None, 12], name="label")
#Y = tf.one_hot(Y, 12).eval(session=tf.Session())
#Y1 = tf.one_hot(Y, 12)
#Y2 = tf.reshape(Y1, [-1, 12])

Kernel1 = tf.get_variable("Kernel1",shape=[3,3,3,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1 = tf.nn.conv2d(X, Kernel1, strides=[1,1,1,1], padding='SAME')+Bias1
Activation1 = tf.nn.relu(Conv1)

Pool1 = tf.nn.max_pool(Activation1, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

Kernel2 = tf.get_variable("Kernel2",shape=[3,3,64,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2 = tf.nn.conv2d(Pool1, Kernel2, strides=[1,1,1,1], padding='SAME')+Bias2
Activation2 = tf.nn.relu(Conv2)

Pool2 = tf.nn.max_pool(Activation2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

Kernel3_1 = tf.get_variable("Kernel3_1",shape=[3,3,128,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_1 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_1 = tf.nn.conv2d(Pool2, Kernel3_1, strides=[1,1,1,1], padding='SAME')+Bias3_1
Activation3_1 = tf.nn.relu(Conv3_1)

Kernel3_2 = tf.get_variable("Kernel3_2",shape=[3,3,256,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_2 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_2 = tf.nn.conv2d(Activation3_1, Kernel3_2, strides=[1,1,1,1], padding='SAME')+Bias3_2
Activation3_2 = tf.nn.relu(Conv3_2)

Pool3 = tf.nn.max_pool(Activation3_2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

Kernel4_1 = tf.get_variable("Kernel4_1",shape=[3,3,256,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_1 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_1 = tf.nn.conv2d(Pool3, Kernel4_1, strides=[1,1,1,1], padding='SAME')+Bias4_1
Activation4_1 = tf.nn.relu(Conv4_1)

Kernel4_2 = tf.get_variable("Kernel4_2",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_2 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_2 = tf.nn.conv2d(Activation4_1, Kernel4_2, strides=[1,1,1,1], padding='SAME')+Bias4_2
Activation4_2 = tf.nn.relu(Conv4_2)

Pool4 = tf.nn.max_pool(Activation4_2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

Kernel5_1 = tf.get_variable("Kernel5_1",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias5_1 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv5_1 = tf.nn.conv2d(Pool4, Kernel5_1, strides=[1,1,1,1], padding='SAME')+Bias5_1
Activation5_1 = tf.nn.relu(Conv5_1)

Kernel5_2 = tf.get_variable("Kernel5_2",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias5_2 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv5_2 = tf.nn.conv2d(Activation5_1, Kernel5_2, strides=[1,1,1,1], padding='SAME')+Bias5_2
Activation5_2 = tf.nn.relu(Conv5_2)

Pool5 = tf.nn.max_pool(Activation5_2, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

W1 = tf.get_variable("W1",shape=[2*2*512, 1024],initializer=tf.contrib.layers.xavier_initializer())
B1 = tf.Variable(tf.truncated_normal(shape=[1024]))
Pool5_flat = tf.reshape(Pool5,[-1,2*2*512])
fc6 = tf.matmul(Pool5_flat,W1)+B1
Activation6 = tf.nn.relu(fc6)

W2 = tf.get_variable("W2",shape=[1024, 12],initializer=tf.contrib.layers.xavier_initializer())
B2 = tf.Variable(tf.truncated_normal(shape=[12]))
OutputLayer = tf.matmul(Activation6 ,W2)+B2

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=OutputLayer, labels=Y))
#optimizer = tf. train.MomentumOptimizer(learning_rate=learning_rate,momentum=0.9).minimize(loss)
optimizer = tf. train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(OutputLayer,1),tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# %%
# Run optimization and test
loss_train_history = []
acc_train_history = []
loss_val_history = []
acc_val_history = []

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    n_batches = int(len(train_images)/batch_size)
    
    for i in range(n_epochs):  
        total_correct_train_preds = 0
        x_train, y_train =_shuffle(train_images, train_labels)
        for k in range(n_batches):
            X_train_batch, Y_train_batch = x_train[k*batch_size:k*batch_size+batch_size], \
                                           y_train[k*batch_size:k*batch_size+batch_size] 
            _, loss_train, OutputLayer_train_batch = sess.run([optimizer, loss, accuracy], \
                                                              feed_dict={X: X_train_batch, Y: Y_train_batch})
            total_correct_train_preds += OutputLayer_train_batch
        train_accuracy = total_correct_train_preds/n_batches
                
        
        # Check validation accuracy
        n_v_batches = int(len(val_images)/batch_size)
        total_correct_val_preds = 0
        for j in range(n_v_batches):
            X_val_batch, Y_val_batch = val_images[j*batch_size:j*batch_size+batch_size], \
                                       val_labels[j*batch_size:j*batch_size+batch_size] 
            loss_val, OutputLayer_val_batch = sess.run([loss, accuracy], feed_dict={X: X_val_batch, \
                                                                                    Y: Y_val_batch})
            total_correct_val_preds += OutputLayer_val_batch
        validation_accuracy = total_correct_val_preds/n_v_batches
           
        print('epoch:%d // train loss:%.3f // train accuracy:%.3f // val loss:%.3f // val accuracy:%.3f' \
              % (i, loss_train, train_accuracy, loss_val, validation_accuracy))
        loss_train_history.append(loss_train)
        acc_train_history.append(train_accuracy)
        loss_val_history.append(loss_val)
        acc_val_history.append(validation_accuracy)
        
        


    # Test the model
    n_batches = int(len(test_images)/batch_size)
    total_correct_test_preds = 0
    for i in range(n_batches):
        X_test_batch, Y_test_batch = test_images[i*batch_size:i*batch_size+batch_size], \
                                     test_labels[i*batch_size:i*batch_size+batch_size]
        OutputLayer_test_batch = sess.run(OutputLayer, feed_dict={X: X_test_batch, Y:Y_test_batch})
        preds = tf.nn.softmax(OutputLayer_test_batch)
        correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_test_batch, 1))
        accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32))
        total_correct_test_preds += sess.run(accuracy)
        
    print ("Test accuracy is {0}".format(total_correct_test_preds/len(test_images)))
# Out:
# epoch:0 // train loss:2.360 // train accuracy:0.122 // val loss:2.229 // val accuracy:0.109
# epoch:1 // train loss:2.418 // train accuracy:0.137 // val loss:2.108 // val accuracy:0.109
# epoch:2 // train loss:2.403 // train accuracy:0.132 // val loss:2.282 // val accuracy:0.135
# epoch:3 // train loss:2.381 // train accuracy:0.139 // val loss:2.162 // val accuracy:0.109
# epoch:4 // train loss:2.419 // train accuracy:0.148 // val loss:2.185 // val accuracy:0.109
# epoch:5 // train loss:2.427 // train accuracy:0.168 // val loss:2.180 // val accuracy:0.164
# epoch:6 // train loss:2.126 // train accuracy:0.227 // val loss:2.074 // val accuracy:0.253
# epoch:7 // train loss:1.774 // train accuracy:0.294 // val loss:2.171 // val accuracy:0.305
# epoch:8 // train loss:1.759 // train accuracy:0.367 // val loss:2.322 // val accuracy:0.339
# epoch:9 // train loss:1.510 // train accuracy:0.407 // val loss:1.763 // val accuracy:0.344
# epoch:10 // train loss:1.563 // train accuracy:0.420 // val loss:2.311 // val accuracy:0.357
# epoch:11 // train loss:1.183 // train accuracy:0.425 // val loss:1.952 // val accuracy:0.372
# epoch:12 // train loss:1.426 // train accuracy:0.452 // val loss:1.837 // val accuracy:0.414
# epoch:13 // train loss:1.507 // train accuracy:0.462 // val loss:1.790 // val accuracy:0.385
# epoch:14 // train loss:1.331 // train accuracy:0.473 // val loss:2.076 // val accuracy:0.404
# epoch:15 // train loss:1.297 // train accuracy:0.486 // val loss:1.858 // val accuracy:0.417
# epoch:16 // train loss:1.281 // train accuracy:0.490 // val loss:1.922 // val accuracy:0.427
# epoch:17 // train loss:1.311 // train accuracy:0.510 // val loss:1.809 // val accuracy:0.448
# epoch:18 // train loss:1.452 // train accuracy:0.520 // val loss:1.872 // val accuracy:0.424
# epoch:19 // train loss:1.478 // train accuracy:0.524 // val loss:1.531 // val accuracy:0.453
# epoch:20 // train loss:1.159 // train accuracy:0.537 // val loss:1.801 // val accuracy:0.445
# epoch:21 // train loss:1.292 // train accuracy:0.543 // val loss:1.674 // val accuracy:0.445
# epoch:22 // train loss:1.386 // train accuracy:0.548 // val loss:1.933 // val accuracy:0.464
# epoch:23 // train loss:1.237 // train accuracy:0.559 // val loss:1.701 // val accuracy:0.479
# epoch:24 // train loss:1.167 // train accuracy:0.574 // val loss:1.605 // val accuracy:0.492
# epoch:25 // train loss:1.236 // train accuracy:0.572 // val loss:1.765 // val accuracy:0.482
# epoch:26 // train loss:1.216 // train accuracy:0.585 // val loss:2.112 // val accuracy:0.466
# epoch:27 // train loss:1.129 // train accuracy:0.596 // val loss:1.692 // val accuracy:0.500
# epoch:28 // train loss:1.288 // train accuracy:0.611 // val loss:1.851 // val accuracy:0.497
# epoch:29 // train loss:1.086 // train accuracy:0.615 // val loss:1.518 // val accuracy:0.565
# epoch:30 // train loss:1.218 // train accuracy:0.634 // val loss:1.631 // val accuracy:0.552
# epoch:31 // train loss:0.990 // train accuracy:0.642 // val loss:1.519 // val accuracy:0.573
# epoch:32 // train loss:1.078 // train accuracy:0.650 // val loss:1.102 // val accuracy:0.565
# epoch:33 // train loss:0.917 // train accuracy:0.659 // val loss:1.298 // val accuracy:0.604
# epoch:34 // train loss:0.829 // train accuracy:0.665 // val loss:1.240 // val accuracy:0.589
# epoch:35 // train loss:0.941 // train accuracy:0.671 // val loss:1.489 // val accuracy:0.604
# epoch:36 // train loss:0.743 // train accuracy:0.685 // val loss:1.293 // val accuracy:0.638
# epoch:37 // train loss:1.144 // train accuracy:0.698 // val loss:1.411 // val accuracy:0.628
# epoch:38 // train loss:0.870 // train accuracy:0.698 // val loss:1.475 // val accuracy:0.628
# epoch:39 // train loss:0.930 // train accuracy:0.704 // val loss:1.540 // val accuracy:0.602
# epoch:40 // train loss:1.162 // train accuracy:0.715 // val loss:1.690 // val accuracy:0.562
# epoch:41 // train loss:0.856 // train accuracy:0.715 // val loss:1.686 // val accuracy:0.617
# epoch:42 // train loss:1.036 // train accuracy:0.718 // val loss:1.165 // val accuracy:0.664
# epoch:43 // train loss:0.786 // train accuracy:0.730 // val loss:1.261 // val accuracy:0.667
# epoch:44 // train loss:0.669 // train accuracy:0.739 // val loss:1.314 // val accuracy:0.594
# epoch:45 // train loss:0.810 // train accuracy:0.735 // val loss:1.456 // val accuracy:0.607
# epoch:46 // train loss:0.636 // train accuracy:0.749 // val loss:1.577 // val accuracy:0.635
# epoch:47 // train loss:0.800 // train accuracy:0.749 // val loss:1.386 // val accuracy:0.654
# epoch:48 // train loss:0.573 // train accuracy:0.765 // val loss:1.251 // val accuracy:0.669
# epoch:49 // train loss:0.718 // train accuracy:0.756 // val loss:0.960 // val accuracy:0.659
# epoch:50 // train loss:0.623 // train accuracy:0.761 // val loss:1.081 // val accuracy:0.669
# epoch:51 // train loss:0.559 // train accuracy:0.771 // val loss:1.111 // val accuracy:0.690
# epoch:52 // train loss:0.680 // train accuracy:0.771 // val loss:1.156 // val accuracy:0.661
# epoch:53 // train loss:0.764 // train accuracy:0.778 // val loss:1.325 // val accuracy:0.664
# epoch:54 // train loss:0.712 // train accuracy:0.775 // val loss:0.920 // val accuracy:0.651
# epoch:55 // train loss:0.868 // train accuracy:0.790 // val loss:1.051 // val accuracy:0.682
# epoch:56 // train loss:0.607 // train accuracy:0.787 // val loss:1.248 // val accuracy:0.672
# epoch:57 // train loss:0.513 // train accuracy:0.802 // val loss:0.846 // val accuracy:0.695
# epoch:58 // train loss:0.552 // train accuracy:0.806 // val loss:1.183 // val accuracy:0.656
# epoch:59 // train loss:0.405 // train accuracy:0.804 // val loss:1.073 // val accuracy:0.672
# epoch:60 // train loss:0.520 // train accuracy:0.813 // val loss:0.951 // val accuracy:0.674
# epoch:61 // train loss:0.675 // train accuracy:0.805 // val loss:1.140 // val accuracy:0.706
# epoch:62 // train loss:0.534 // train accuracy:0.813 // val loss:1.463 // val accuracy:0.641
# epoch:63 // train loss:0.460 // train accuracy:0.821 // val loss:1.008 // val accuracy:0.693
# epoch:64 // train loss:0.533 // train accuracy:0.821 // val loss:1.391 // val accuracy:0.633
# epoch:65 // train loss:0.487 // train accuracy:0.822 // val loss:1.319 // val accuracy:0.643
# epoch:66 // train loss:0.438 // train accuracy:0.822 // val loss:1.268 // val accuracy:0.690
# epoch:67 // train loss:0.526 // train accuracy:0.824 // val loss:1.104 // val accuracy:0.672
# epoch:68 // train loss:0.640 // train accuracy:0.836 // val loss:1.046 // val accuracy:0.698
# epoch:69 // train loss:0.515 // train accuracy:0.835 // val loss:1.396 // val accuracy:0.669
# epoch:70 // train loss:0.675 // train accuracy:0.833 // val loss:1.281 // val accuracy:0.674
# epoch:71 // train loss:0.450 // train accuracy:0.849 // val loss:1.009 // val accuracy:0.688
# epoch:72 // train loss:0.420 // train accuracy:0.849 // val loss:1.124 // val accuracy:0.685
# epoch:73 // train loss:0.473 // train accuracy:0.861 // val loss:1.185 // val accuracy:0.682
# epoch:74 // train loss:0.487 // train accuracy:0.848 // val loss:1.285 // val accuracy:0.677
# epoch:75 // train loss:0.513 // train accuracy:0.855 // val loss:1.182 // val accuracy:0.698
# epoch:76 // train loss:0.464 // train accuracy:0.857 // val loss:1.751 // val accuracy:0.661
# epoch:77 // train loss:0.432 // train accuracy:0.857 // val loss:0.958 // val accuracy:0.674
# epoch:78 // train loss:0.650 // train accuracy:0.854 // val loss:1.851 // val accuracy:0.664
# epoch:79 // train loss:0.442 // train accuracy:0.858 // val loss:1.326 // val accuracy:0.622
# epoch:80 // train loss:0.431 // train accuracy:0.853 // val loss:1.208 // val accuracy:0.706
# epoch:81 // train loss:0.331 // train accuracy:0.872 // val loss:1.316 // val accuracy:0.661
# epoch:82 // train loss:0.355 // train accuracy:0.867 // val loss:1.078 // val accuracy:0.690
# epoch:83 // train loss:0.616 // train accuracy:0.873 // val loss:1.203 // val accuracy:0.714
# epoch:84 // train loss:0.271 // train accuracy:0.874 // val loss:1.326 // val accuracy:0.677
# epoch:85 // train loss:0.377 // train accuracy:0.881 // val loss:1.095 // val accuracy:0.711
# epoch:86 // train loss:0.459 // train accuracy:0.881 // val loss:1.335 // val accuracy:0.706
# epoch:87 // train loss:0.213 // train accuracy:0.887 // val loss:1.075 // val accuracy:0.690
# epoch:88 // train loss:0.281 // train accuracy:0.890 // val loss:1.454 // val accuracy:0.669
# epoch:89 // train loss:0.429 // train accuracy:0.890 // val loss:1.587 // val accuracy:0.688
# epoch:90 // train loss:0.423 // train accuracy:0.892 // val loss:0.904 // val accuracy:0.701
# epoch:91 // train loss:0.254 // train accuracy:0.886 // val loss:1.327 // val accuracy:0.716
# epoch:92 // train loss:0.397 // train accuracy:0.891 // val loss:0.938 // val accuracy:0.703
# epoch:93 // train loss:0.249 // train accuracy:0.899 // val loss:1.376 // val accuracy:0.693
# epoch:94 // train loss:0.319 // train accuracy:0.902 // val loss:1.210 // val accuracy:0.703
# epoch:95 // train loss:0.207 // train accuracy:0.905 // val loss:1.335 // val accuracy:0.688
# epoch:96 // train loss:0.364 // train accuracy:0.910 // val loss:1.299 // val accuracy:0.680
# epoch:97 // train loss:0.215 // train accuracy:0.904 // val loss:1.448 // val accuracy:0.674
# epoch:98 // train loss:0.243 // train accuracy:0.907 // val loss:1.360 // val accuracy:0.714
# epoch:99 // train loss:0.239 // train accuracy:0.915 // val loss:1.279 // val accuracy:0.682
# Test accuracy is 0.6666666666666666

# %%
plt.subplot(2,1,1)
plt.plot(loss_train_history, 'b-', label='Train loss value')
plt.plot(loss_val_history, 'r-', label='Val. loss value')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(ncol=2, loc='upper right')

plt.subplot(2,1,2)
plt.plot(acc_train_history, 'b-', label='Train accuracy value')
plt.plot(acc_val_history, 'r-', label='Val. accuracy value')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(10, 10)
plt.show()
