# %%
! nvcc --version
# !cat /usr/local/cuda-9.0/include/cudnn.h | grep CUDNN_MAJOR -A 2

# %%
import tensorflow as tf
# !cat /usr/local/cuda-9.0/include/cudnn.h | grep CUDNN_MAJOR -A 2
tf.__version__
# Out:
# '1.8.0'

# %%
import sys
import os
import cv2
import time
import glob
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib inline

train_folder = 'Dataset/train'
val_folder = 'Dataset/validation'
test_folder = 'Dataset/test'

def _minmax_scaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    
    return numerator / (denominator + 1e-7)


def _one_hot(idx):
    idx = tf.one_hot(np.array(idx), 12).eval(session=tf.Session())
    
    return idx

def _shuffle(images, labels):
    tmp = [[x,y] for x, y in zip(images, labels)]
    random.shuffle(tmp)
    shuffle_images = [n[0] for n in tmp]
    shuffle_labels = [n[1] for n in tmp]
    
    return shuffle_images, shuffle_labels

def _data_load(folder_path):
    images = []
    labels = []
    folder_list = os.listdir(folder_path)
    for i, v in enumerate(folder_list):
        image_path = glob.glob(os.path.join(folder_path,v,'*.png')) 
        for j in image_path:
            images.append(cv2.imread(j))
            labels.append(i)
        
    return _minmax_scaler(images), _one_hot(labels)


train_images, train_labels = _data_load(train_folder)
val_images, val_labels = _data_load(val_folder)
test_images, test_labels = _data_load(test_folder)

print("train_images shape: ", np.array(train_images).shape, "// type: ", type(np.array(train_images)))
print("train_labels shape: ", np.array(train_labels).shape, "// type: ", type(np.array(train_labels)))
print("validation_images shape: ", np.array(val_images).shape, "// type: ", type(np.array(val_images)))
print("validation_labels shape: ", np.array(val_labels).shape, "// type: ", type(np.array(val_labels)))
print("test_images shape: ", np.array(test_images).shape, "// type: ", type(np.array(test_images)))
print("test_labels shape: ", np.array(test_labels).shape, "// type: ", type(np.array(test_labels)))
# Out:
# train_images shape:  (3847, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# train_labels shape:  (3847, 12) // type:  <class 'numpy.ndarray'>
# validation_images shape:  (447, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# validation_labels shape:  (447, 12) // type:  <class 'numpy.ndarray'>
# test_images shape:  (456, 64, 64, 3) // type:  <class 'numpy.ndarray'>
# test_labels shape:  (456, 12) // type:  <class 'numpy.ndarray'>

# %%
learning_rate = 0.00001
batch_size = 64
n_epochs = 100

# Create placeholders
X = tf.placeholder(tf.float32,shape=[None,64,64,3], name="image")
Y = tf.placeholder(tf.int32,[None, 12], name="label")
#Y = tf.one_hot(Y, 12).eval(session=tf.Session())
#Y1 = tf.one_hot(Y, 12)
#Y2 = tf.reshape(Y1, [-1, 12])

#64x64x64
Kernel1_1 = tf.get_variable("Kernel1_1",shape=[3,3,3,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1_1 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1_1 = tf.nn.conv2d(X, Kernel1_1, strides=[1,1,1,1], padding='SAME')+Bias1_1
Activation1_1 = tf.nn.relu(Conv1_1)

#64x64x64
Kernel1_2 = tf.get_variable("Kernel1_2",shape=[3,3,64,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1_2 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1_2 = tf.nn.conv2d(Activation1_1, Kernel1_2, strides=[1,1,1,1], padding='SAME')+Bias1_2
Activation1_2 = tf.nn.relu(Conv1_2)

#64x64x64
Kernel1_3 = tf.get_variable("Kernel1_3",shape=[3,3,64,64],initializer=tf.contrib.layers.xavier_initializer())
Bias1_3 = tf.Variable(tf.truncated_normal(shape=[64],stddev=0.1))
Conv1_3 = tf.nn.conv2d(Activation1_2, Kernel1_3, strides=[1,1,1,1], padding='SAME')+Bias1_3
Activation1_3 = tf.nn.relu(Conv1_3)

#32x32x64
Pool1 = tf.nn.max_pool(Activation1_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#32x32x128
Kernel2_1 = tf.get_variable("Kernel2_1",shape=[3,3,64,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2_1 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2_1 = tf.nn.conv2d(Pool1, Kernel2_1, strides=[1,1,1,1], padding='SAME')+Bias2_1
Activation2_1 = tf.nn.relu(Conv2_1)

#32x32x128
Kernel2_2 = tf.get_variable("Kernel2_2",shape=[3,3,128,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2_2 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2_2 = tf.nn.conv2d(Activation2_1, Kernel2_2, strides=[1,1,1,1], padding='SAME')+Bias2_2
Activation2_2 = tf.nn.relu(Conv2_2)

#32x32x128
Kernel2_3 = tf.get_variable("Kernel2_3",shape=[3,3,128,128],initializer=tf.contrib.layers.xavier_initializer())
Bias2_3 = tf.Variable(tf.truncated_normal(shape=[128],stddev=0.1))
Conv2_3 = tf.nn.conv2d(Activation2_2, Kernel2_3, strides=[1,1,1,1], padding='SAME')+Bias2_3
Activation2_3 = tf.nn.relu(Conv2_3)

#16x16x128
Pool2 = tf.nn.max_pool(Activation2_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#16x16x256
Kernel3_1 = tf.get_variable("Kernel3_1",shape=[3,3,128,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_1 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_1 = tf.nn.conv2d(Pool2, Kernel3_1, strides=[1,1,1,1], padding='SAME')+Bias3_1
Activation3_1 = tf.nn.relu(Conv3_1)

#16x16x256
Kernel3_2 = tf.get_variable("Kernel3_2",shape=[3,3,256,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_2 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_2 = tf.nn.conv2d(Activation3_1, Kernel3_2, strides=[1,1,1,1], padding='SAME')+Bias3_2
Activation3_2 = tf.nn.relu(Conv3_2)

#16x16x256
## Add DCNN Layer 1
Kernel3_3 = tf.get_variable("Kernel3_3",shape=[3,3,256,256],initializer=tf.contrib.layers.xavier_initializer())
Bias3_3 = tf.Variable(tf.truncated_normal(shape=[256],stddev=0.1))
Conv3_3 = tf.nn.conv2d(Activation3_2, Kernel3_3, strides=[1,1,1,1], padding='SAME')+Bias3_3
Activation3_3 = tf.nn.relu(Conv3_3)

#8x8x512
Pool3 = tf.nn.max_pool(Activation3_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#8x8x512
## Add DCNN Layer 2
Kernel4_1 = tf.get_variable("Kernel4_1",shape=[3,3,256,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_1 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_1 = tf.nn.conv2d(Pool3, Kernel4_1, strides=[1,1,1,1], padding='SAME')+Bias4_1
Activation4_1 = tf.nn.relu(Conv4_1)

#8x8x512
## Add DCNN Layer 3
Kernel4_2 = tf.get_variable("Kernel4_2",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_2 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_2 = tf.nn.conv2d(Activation4_1, Kernel4_2, strides=[1,1,1,1], padding='SAME')+Bias4_2
Activation4_2 = tf.nn.relu(Conv4_2)

#8x8x512
## Add DCNN Layer 4
Kernel4_3 = tf.get_variable("Kernel4_3",shape=[3,3,512,512],initializer=tf.contrib.layers.xavier_initializer())
Bias4_3 = tf.Variable(tf.truncated_normal(shape=[512],stddev=0.1))
Conv4_3 = tf.nn.conv2d(Activation4_2, Kernel4_3, strides=[1,1,1,1], padding='SAME')+Bias4_3
Activation4_3 = tf.nn.relu(Conv4_3)

#4x4x512
Pool4 = tf.nn.max_pool(Activation4_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

#4x4x1024
## Add DCNN Layer 5
Kernel5_1 = tf.get_variable("Kernel5_1",shape=[3,3,512,1024],initializer=tf.contrib.layers.xavier_initializer())
Bias5_1 = tf.Variable(tf.truncated_normal(shape=[1024],stddev=0.1))
Conv5_1 = tf.nn.conv2d(Pool4, Kernel5_1, strides=[1,1,1,1], padding='SAME')+Bias5_1
Activation5_1 = tf.nn.relu(Conv5_1)

#4x4x1024
## Add DCNN Layer 6
Kernel5_2 = tf.get_variable("Kernel5_2",shape=[3,3,1024,1024],initializer=tf.contrib.layers.xavier_initializer())
Bias5_2 = tf.Variable(tf.truncated_normal(shape=[1024],stddev=0.1))
Conv5_2 = tf.nn.conv2d(Activation5_1, Kernel5_2, strides=[1,1,1,1], padding='SAME')+Bias5_2
Activation5_2 = tf.nn.relu(Conv5_2)

#4x4x1024
## Add DCNN Layer 7
Kernel5_3 = tf.get_variable("Kernel5_3",shape=[3,3,1024,2048],initializer=tf.contrib.layers.xavier_initializer())
Bias5_3 = tf.Variable(tf.truncated_normal(shape=[2048],stddev=0.1))
Conv5_3 = tf.nn.conv2d(Activation5_2, Kernel5_3, strides=[1,1,1,1], padding='SAME')+Bias5_3
Activation5_3 = tf.nn.relu(Conv5_3)

#2x2x1024
Pool5 = tf.nn.max_pool(Activation5_3, ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

W1 = tf.get_variable("W1",shape=[2*2*2048, 2048],initializer=tf.contrib.layers.xavier_initializer())
B1 = tf.Variable(tf.truncated_normal(shape=[2048]))
Pool5_flat = tf.reshape(Pool5,[-1,2*2*2048])
fc6 = tf.matmul(Pool5_flat,W1)+B1
Activation6 = tf.nn.relu(fc6)

W2 = tf.get_variable("W2",shape=[2048, 12],initializer=tf.contrib.layers.xavier_initializer())
B2 = tf.Variable(tf.truncated_normal(shape=[12]))
OutputLayer = tf.matmul(Activation6 ,W2)+B2

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=OutputLayer, labels=Y))
#optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate,momentum=0.9).minimize(loss)
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

correct_prediction = tf.equal(tf.argmax(OutputLayer,1),tf.argmax(Y,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

# %%
# Run optimization and test
loss_train_history = []
acc_train_history = []
loss_val_history = []
acc_val_history = []

init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(init)
    n_batches = int(len(train_images)/batch_size)
    
    for i in range(n_epochs):  
        total_correct_train_preds = 0
        x_train, y_train =_shuffle(train_images, train_labels)
        for k in range(n_batches):
            X_train_batch, Y_train_batch = x_train[k*batch_size:k*batch_size+batch_size], \
                                           y_train[k*batch_size:k*batch_size+batch_size] 
            _, loss_train, OutputLayer_train_batch = sess.run([optimizer, loss, accuracy], \
                                                              feed_dict={X: X_train_batch, Y: Y_train_batch})
            total_correct_train_preds += OutputLayer_train_batch
        train_accuracy = total_correct_train_preds/n_batches
                
        
        # Check validation accuracy
        n_v_batches = int(len(val_images)/batch_size)
        total_correct_val_preds = 0
        for j in range(n_v_batches):
            X_val_batch, Y_val_batch = val_images[j*batch_size:j*batch_size+batch_size], \
                                       val_labels[j*batch_size:j*batch_size+batch_size] 
            loss_val, OutputLayer_val_batch = sess.run([loss, accuracy], feed_dict={X: X_val_batch, \
                                                                                    Y: Y_val_batch})
            total_correct_val_preds += OutputLayer_val_batch
        validation_accuracy = total_correct_val_preds/n_v_batches
           
        print('epoch:%d // train loss:%.3f // train accuracy:%.3f // val loss:%.3f // val accuracy:%.3f' \
              % (i, loss_train, train_accuracy, loss_val, validation_accuracy))
        loss_train_history.append(loss_train)
        acc_train_history.append(train_accuracy)
        loss_val_history.append(loss_val)
        acc_val_history.append(validation_accuracy)
        
        


    # Test the model
    n_batches = int(len(test_images)/batch_size)
    total_correct_test_preds = 0
    for i in range(n_batches):
        X_test_batch, Y_test_batch = test_images[i*batch_size:i*batch_size+batch_size], \
                                     test_labels[i*batch_size:i*batch_size+batch_size]
        OutputLayer_test_batch = sess.run(OutputLayer, feed_dict={X: X_test_batch, Y:Y_test_batch})
        preds = tf.nn.softmax(OutputLayer_test_batch)
        correct_preds = tf.equal(tf.argmax(preds, 1), tf.argmax(Y_test_batch, 1))
        accuracy = tf.reduce_sum(tf.cast(correct_preds, tf.float32))
        total_correct_test_preds += sess.run(accuracy)
        
    print ("Test accuracy is {0}".format(total_correct_test_preds/len(test_images)))
    
    saver.save(sess, "my_model/model_7L_3v.ckpt")
# Out:
# epoch:0 // train loss:2.449 // train accuracy:0.130 // val loss:2.226 // val accuracy:0.109
# epoch:1 // train loss:2.364 // train accuracy:0.142 // val loss:2.293 // val accuracy:0.109
# epoch:2 // train loss:2.390 // train accuracy:0.137 // val loss:2.238 // val accuracy:0.135
# epoch:3 // train loss:2.374 // train accuracy:0.136 // val loss:2.260 // val accuracy:0.109
# epoch:4 // train loss:2.436 // train accuracy:0.127 // val loss:2.238 // val accuracy:0.109
# epoch:5 // train loss:2.325 // train accuracy:0.142 // val loss:2.159 // val accuracy:0.109
# epoch:6 // train loss:2.195 // train accuracy:0.170 // val loss:1.987 // val accuracy:0.232
# epoch:7 // train loss:1.744 // train accuracy:0.296 // val loss:2.279 // val accuracy:0.307
# epoch:8 // train loss:1.799 // train accuracy:0.371 // val loss:1.888 // val accuracy:0.336
# epoch:9 // train loss:1.296 // train accuracy:0.416 // val loss:1.830 // val accuracy:0.349
# epoch:10 // train loss:1.415 // train accuracy:0.429 // val loss:1.738 // val accuracy:0.367
# epoch:11 // train loss:1.683 // train accuracy:0.464 // val loss:1.551 // val accuracy:0.411
# epoch:12 // train loss:1.329 // train accuracy:0.486 // val loss:1.508 // val accuracy:0.398
# epoch:13 // train loss:1.165 // train accuracy:0.512 // val loss:1.649 // val accuracy:0.453
# epoch:14 // train loss:1.174 // train accuracy:0.531 // val loss:1.414 // val accuracy:0.443
# epoch:15 // train loss:1.218 // train accuracy:0.543 // val loss:1.573 // val accuracy:0.490
# epoch:16 // train loss:1.173 // train accuracy:0.575 // val loss:1.682 // val accuracy:0.490
# epoch:17 // train loss:0.958 // train accuracy:0.610 // val loss:1.518 // val accuracy:0.526
# epoch:18 // train loss:1.081 // train accuracy:0.629 // val loss:1.279 // val accuracy:0.536
# epoch:19 // train loss:1.101 // train accuracy:0.653 // val loss:1.264 // val accuracy:0.565
# epoch:20 // train loss:1.070 // train accuracy:0.661 // val loss:2.166 // val accuracy:0.531
# epoch:21 // train loss:1.008 // train accuracy:0.679 // val loss:1.391 // val accuracy:0.562
# epoch:22 // train loss:0.755 // train accuracy:0.699 // val loss:1.803 // val accuracy:0.570
# epoch:23 // train loss:0.826 // train accuracy:0.707 // val loss:0.733 // val accuracy:0.596
# epoch:24 // train loss:0.667 // train accuracy:0.737 // val loss:1.587 // val accuracy:0.591
# epoch:25 // train loss:0.716 // train accuracy:0.741 // val loss:0.954 // val accuracy:0.612
# epoch:26 // train loss:0.489 // train accuracy:0.759 // val loss:0.905 // val accuracy:0.661
# epoch:27 // train loss:0.569 // train accuracy:0.759 // val loss:1.610 // val accuracy:0.591
# epoch:28 // train loss:0.654 // train accuracy:0.792 // val loss:1.610 // val accuracy:0.604
# epoch:29 // train loss:0.679 // train accuracy:0.778 // val loss:0.789 // val accuracy:0.625
# epoch:30 // train loss:0.587 // train accuracy:0.788 // val loss:0.894 // val accuracy:0.635
# epoch:31 // train loss:0.828 // train accuracy:0.823 // val loss:1.662 // val accuracy:0.586
# epoch:32 // train loss:0.478 // train accuracy:0.827 // val loss:1.017 // val accuracy:0.622
# epoch:33 // train loss:0.593 // train accuracy:0.819 // val loss:2.117 // val accuracy:0.568
# epoch:34 // train loss:0.412 // train accuracy:0.833 // val loss:1.137 // val accuracy:0.633
# epoch:35 // train loss:0.343 // train accuracy:0.857 // val loss:1.297 // val accuracy:0.625
# epoch:36 // train loss:0.466 // train accuracy:0.859 // val loss:1.313 // val accuracy:0.641
# epoch:37 // train loss:0.460 // train accuracy:0.862 // val loss:1.161 // val accuracy:0.643
# epoch:38 // train loss:0.513 // train accuracy:0.872 // val loss:1.368 // val accuracy:0.643
# epoch:39 // train loss:0.450 // train accuracy:0.863 // val loss:1.244 // val accuracy:0.643
# epoch:40 // train loss:0.379 // train accuracy:0.896 // val loss:1.309 // val accuracy:0.641
# epoch:41 // train loss:0.184 // train accuracy:0.898 // val loss:1.077 // val accuracy:0.628
# epoch:42 // train loss:0.216 // train accuracy:0.890 // val loss:0.900 // val accuracy:0.672
# epoch:43 // train loss:0.262 // train accuracy:0.895 // val loss:1.514 // val accuracy:0.620
# epoch:44 // train loss:0.289 // train accuracy:0.896 // val loss:1.039 // val accuracy:0.669
# epoch:45 // train loss:0.194 // train accuracy:0.906 // val loss:1.149 // val accuracy:0.648
# epoch:46 // train loss:0.316 // train accuracy:0.922 // val loss:1.297 // val accuracy:0.682
# epoch:47 // train loss:0.421 // train accuracy:0.915 // val loss:1.635 // val accuracy:0.604
# epoch:48 // train loss:0.626 // train accuracy:0.905 // val loss:2.347 // val accuracy:0.625
# epoch:49 // train loss:0.268 // train accuracy:0.860 // val loss:1.661 // val accuracy:0.612
# epoch:50 // train loss:0.228 // train accuracy:0.923 // val loss:1.426 // val accuracy:0.648
# epoch:51 // train loss:0.404 // train accuracy:0.930 // val loss:2.607 // val accuracy:0.602
# epoch:52 // train loss:0.223 // train accuracy:0.907 // val loss:0.968 // val accuracy:0.635
# epoch:53 // train loss:0.230 // train accuracy:0.922 // val loss:1.173 // val accuracy:0.628
# epoch:54 // train loss:0.177 // train accuracy:0.929 // val loss:1.331 // val accuracy:0.680
# epoch:55 // train loss:0.192 // train accuracy:0.944 // val loss:1.208 // val accuracy:0.654
# epoch:56 // train loss:0.262 // train accuracy:0.941 // val loss:2.544 // val accuracy:0.604
# epoch:57 // train loss:0.303 // train accuracy:0.930 // val loss:1.123 // val accuracy:0.661
# epoch:58 // train loss:0.208 // train accuracy:0.927 // val loss:2.027 // val accuracy:0.646
# epoch:59 // train loss:0.190 // train accuracy:0.914 // val loss:0.970 // val accuracy:0.630
# epoch:60 // train loss:0.125 // train accuracy:0.943 // val loss:1.394 // val accuracy:0.661
# epoch:61 // train loss:0.182 // train accuracy:0.957 // val loss:1.540 // val accuracy:0.638
# epoch:62 // train loss:0.163 // train accuracy:0.953 // val loss:1.249 // val accuracy:0.638
# epoch:63 // train loss:0.049 // train accuracy:0.954 // val loss:1.562 // val accuracy:0.651
# epoch:64 // train loss:0.105 // train accuracy:0.960 // val loss:1.201 // val accuracy:0.661
# epoch:65 // train loss:0.109 // train accuracy:0.961 // val loss:1.514 // val accuracy:0.656
# epoch:66 // train loss:0.379 // train accuracy:0.947 // val loss:1.227 // val accuracy:0.641
# epoch:67 // train loss:0.113 // train accuracy:0.934 // val loss:1.695 // val accuracy:0.656
# epoch:68 // train loss:0.088 // train accuracy:0.951 // val loss:1.511 // val accuracy:0.648
# epoch:69 // train loss:0.140 // train accuracy:0.957 // val loss:1.047 // val accuracy:0.669
# epoch:70 // train loss:0.089 // train accuracy:0.959 // val loss:1.086 // val accuracy:0.654
# epoch:71 // train loss:0.202 // train accuracy:0.944 // val loss:2.655 // val accuracy:0.643
# epoch:72 // train loss:0.054 // train accuracy:0.959 // val loss:1.589 // val accuracy:0.688
# epoch:73 // train loss:0.144 // train accuracy:0.966 // val loss:1.472 // val accuracy:0.654
# epoch:74 // train loss:0.047 // train accuracy:0.973 // val loss:2.015 // val accuracy:0.646
# epoch:75 // train loss:0.085 // train accuracy:0.971 // val loss:2.143 // val accuracy:0.638
# epoch:76 // train loss:0.107 // train accuracy:0.976 // val loss:2.238 // val accuracy:0.643
# epoch:77 // train loss:0.179 // train accuracy:0.977 // val loss:1.964 // val accuracy:0.674
# epoch:78 // train loss:0.026 // train accuracy:0.975 // val loss:1.893 // val accuracy:0.656
# epoch:79 // train loss:0.125 // train accuracy:0.976 // val loss:1.911 // val accuracy:0.641
# epoch:80 // train loss:0.199 // train accuracy:0.948 // val loss:3.410 // val accuracy:0.599
# epoch:81 // train loss:0.164 // train accuracy:0.950 // val loss:1.841 // val accuracy:0.641
# epoch:82 // train loss:0.117 // train accuracy:0.968 // val loss:2.122 // val accuracy:0.633
# epoch:83 // train loss:0.084 // train accuracy:0.955 // val loss:2.977 // val accuracy:0.617
# epoch:84 // train loss:0.063 // train accuracy:0.971 // val loss:1.418 // val accuracy:0.646
# epoch:85 // train loss:0.071 // train accuracy:0.971 // val loss:1.822 // val accuracy:0.638
# epoch:86 // train loss:0.083 // train accuracy:0.969 // val loss:1.704 // val accuracy:0.664
# epoch:87 // train loss:0.059 // train accuracy:0.978 // val loss:1.596 // val accuracy:0.664
# epoch:88 // train loss:0.063 // train accuracy:0.972 // val loss:2.710 // val accuracy:0.664
# epoch:89 // train loss:0.106 // train accuracy:0.981 // val loss:2.578 // val accuracy:0.648
# epoch:90 // train loss:0.018 // train accuracy:0.988 // val loss:1.905 // val accuracy:0.648
# epoch:91 // train loss:0.101 // train accuracy:0.985 // val loss:2.431 // val accuracy:0.641
# epoch:92 // train loss:0.138 // train accuracy:0.978 // val loss:2.613 // val accuracy:0.643
# epoch:93 // train loss:0.064 // train accuracy:0.959 // val loss:1.579 // val accuracy:0.651
# epoch:94 // train loss:0.077 // train accuracy:0.973 // val loss:1.966 // val accuracy:0.651
# epoch:95 // train loss:0.048 // train accuracy:0.982 // val loss:1.443 // val accuracy:0.674
# epoch:96 // train loss:0.111 // train accuracy:0.988 // val loss:1.893 // val accuracy:0.651
# epoch:97 // train loss:0.216 // train accuracy:0.983 // val loss:3.243 // val accuracy:0.565
# epoch:98 // train loss:0.107 // train accuracy:0.978 // val loss:2.021 // val accuracy:0.641
# epoch:99 // train loss:0.013 // train accuracy:0.988 // val loss:1.617 // val accuracy:0.672
# Test accuracy is 0.6578947368421053

# %%
plt.subplot(2,1,1)
plt.plot(loss_train_history, 'b-', label='Train loss value')
plt.plot(loss_val_history, 'r-', label='Val. loss value')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.legend(ncol=2, loc='upper right')

plt.subplot(2,1,2)
plt.plot(acc_train_history, 'b-', label='Train accuracy value')
plt.plot(acc_val_history, 'r-', label='Val. accuracy value')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(10, 10)
plt.show()
